# %%
#In the name of God##
import torch
import random
import numpy as np
from run import go_model
from utils.tools import dotdict

# %%
fix_seed = 2022
random.seed(fix_seed)
torch.manual_seed(fix_seed)

np.random.seed(fix_seed)

args = dotdict()

# basic config
args.is_training = 1                  #  hint: statu
args.model_id = 'test'                #  hint: model id for saving
args.model = 'IndRNN'          #  hint: model name, options: FFTransformer, Autoformer, LSTM, MLP, Informer, IndRNN
#                                                          options: Transformer, LogSparse, persistence
#                                                          And same with GraphXxxx, like: GraphTransformer, GraphLSTM, and ..
args.plot_flag  =  1                  #  hint:  Whether to save loss plots or not
args.test_dir = 'custom/'                    #  hint:  Base dir to save test results
args.verbose = 1                      #  hint:  Whether to print inter-epoch losses

# data loader
args.data = 'Custom'                                              # hint: dataset type, Wind or WindGraph
args.root_path = 'custom/dataset/'          # hint:  root path of the data file
args.data_path = 'data.csv'                                # hint:  data file
args.target = 'Close'                                # hint:  optional target station for non-graph models
args.scale = True
args.freq = 'b'                                                 # hint:  freq for time features encoding:
#                                                                      options: [ s:secondly, t:minutely, h:hourly, 
#                                                                      options:   d:daily, b:business days, w:weekly, m:monthly]
#                                                                      options:   You can also use more detailed freq like 15min or 3h
args.checkpoints = 'custom/checkpoints/'                              # hint: location of model checkpoints
args.checkpoint_flag = 1                                        # hint: Whether to checkpoint or not
args.n_closest = None                                           # hint: number of closest nodes for graph connectivity, None --> complete graph
args.all_stations = 0                                           # hint: Whether to use all stations or just target for non-spatial models
args.data_step = 1                                              # hint: Only use every nth point. Set data_step  =  1 for full dataset
args.min_num_nodes = 2                                          # hint: Minimum number of nodes in a graph

# forecasting task
args.features = 'S'          # hint:  forecasting task, options:[M, S]; M:multivariate input, S:univariate input
args.seq_len = 5             # hint: input sequence length
args.label_len = 1           # hint: start token length. Note that Graph models only use label_len and pred_len
args.pred_len = 1            # hint: prediction sequence length
args.enc_in = 1              # hint: Number of encoder input features
args.dec_in = 1              # hint: Number of decoder input features
args.c_out = 1               # hint: output size, note that it is assumed that the target features are placed last

# model define
args.d_model = 512                           # hint: dimension of model
args.n_heads = 8                             # hint: num of heads
args.e_layers = 2                            # hint: number of encoder layers for non-spatial and number of LSTM or MLP layers for GraphLSTM and GraphMLP
args.d_layers = 2                            # hint: num of decoder layers
args.gnn_layers = 2                          # hint: Number of sequential graph blocks in GNN
args.d_ff = 2048                             # hint: dimension of fcn
args.moving_avg = 25                         # hint: window size of moving average for Autoformer
args.factor = 3                              # hint: attn factor
args.distil = True                           # hint: whether to use distilling in encoder, using this argument means not using distilling, not used for GNN models
args.dropout = 0.05                          # hint: dropout
args.embed = 'timeF'                         # hint = time features encoding, options:[timeF, fixed, learned]
args.activation = 'gelu'                     # hint:  activation
args.output_attention  =  False              # hint = whether to output attention in ecoder, action:store_true
args.win_len = 6                             # hint: Local attention length for LogSparse Transformer
args.res_len = None                          # hint: Restart attention length for LogSparse Transformer
args.qk_ker = 4                              # hint: Key/Query convolution kernel length for LogSparse Transformer
args.v_conv = 0                              # hint: Weather to apply ConvAttn for values (in addition to K/Q for LogSparseAttn)
args.sparse_flag = 1                         # hint: Weather to apply logsparse mask for LogSparse Transformer
args.top_keys = 0                            # hint: Weather to find top keys instead of queries in Informer
args.kernel_size = 3                         # hint: Kernel size for the 1DConv value embedding
args.train_strat_lstm = 'recursive'          # hint: The training strategy to use for the LSTM model. recursive or mixed_teacher_forcing
args.norm_out = 1                            # hint: Whether to apply laynorm to outputs of Enc or Dec in FFTransformer
args.num_decomp = 4                          # hint: Number of wavelet decompositions for FFTransformer
args.mlp_out = 0                             # hint: Whether to apply MLP to GNN outputs

# Optimization
args.num_workers = 1                  # hint: data loader num workers
args.itr = 1                          # hint: experiments times
args.train_epochs = 10                # hint: train epochs
args.batch_size = 32                  # hint: batch size of train input data
args.patience = 5                     # hint: early stopping patience
args.learning_rate  =  0.001          # hint: optimizer learning rate
args.lr_decay_rate  =  0.8            # hint: Rate for which to decay lr with
args.des = 'test'                     # hint:  exp description
args.loss = 'mse'                     # hint:  loss function
args.lradj = 'type1'                  # hint:  adjust learning rate

# GPU
args.use_gpu  =  True          # hint: use gpu
args.gpu  =  0                 # hint: gpu

# multi-gpu is not fully developed yet and still experimental for graph data.
args.use_multi_gpu = False          # hint: should use multiple gpus ? , action: store_true, 
args.devices = '0,1,2,3'            # hint: device ids of multiple gpus


# added options
args.criteria = 'default'               # hint: kind of measure for selecting criterion, options: 'SmoothL1', 'Huber', 'L1'
#                                            default is -> MSE   !  Cation! THe VaLUe FoR thIS PArT is CASE-SENSITIVE !
args.kind_of_optim = 'default'          # hint: kind of optimizer to use, default is Adam
args.kind_of_scaler = 'MinMax'

# %%
model, setting = go_model(args)
# Out:
# Args in experiment:
# {'is_training': 1, 'model_id': 'test', 'model': 'IndRNN', 'plot_flag': 1, 'test_dir': 'custom/', 'verbose': 1, 'data': 'Custom', 'root_path': 'custom/dataset/', 'data_path': 'data.csv', 'target': 'Close', 'scale': True, 'freq': 'b', 'checkpoints': 'custom/checkpoints/', 'checkpoint_flag': 1, 'n_closest': None, 'all_stations': 0, 'data_step': 1, 'min_num_nodes': 2, 'features': 'S', 'seq_len': 5, 'label_len': 1, 'pred_len': 1, 'enc_in': 1, 'dec_in': 1, 'c_out': 1, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 2, 'gnn_layers': 2, 'd_ff': 2048, 'moving_avg': 25, 'factor': 3, 'distil': True, 'dropout': 0.05, 'embed': 'timeF', 'activation': 'gelu', 'output_attention': False, 'win_len': 6, 'res_len': None, 'qk_ker': 4, 'v_conv': 0, 'sparse_flag': 1, 'top_keys': 0, 'kernel_size': 3, 'train_strat_lstm': 'recursive', 'norm_out': 1, 'num_decomp': 4, 'mlp_out': 0, 'num_workers': 1, 'itr': 1, 'train_epochs': 10, 'batch_size': 32, 'patience': 5, 'learning_rate': 0.001, 'lr_decay_rate': 0.8, 'des': 'test', 'loss': 'mse', 'lradj': 'type1', 'use_gpu': False, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'criteria': 'default', 'kind_of_optim': 'default', 'kind_of_scaler': 'MinMax'}
# Use CPU
# >>>>>>>start training : test_IndRNN_Custom_ftS_sl5_ll1_pl1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 3684
# test 3684
# Could not load best model
# Updating learning rate to 0.001
# 	iters: 100/115, epoch: 1 | loss: 0.0898443
# Epoch: 1 cost time: 1.8730170726776123
# Epoch: 1, Steps: 115 | Train Loss: 0.0877015 Test Loss 0.0664827
# Validation loss decreased (inf --> 0.066483).  Saving model ...
# Updating learning rate to 0.0008
# 	iters: 100/115, epoch: 2 | loss: 0.0580888
# Epoch: 2 cost time: 1.7924375534057617
# Epoch: 2, Steps: 115 | Train Loss: 0.0563820 Test Loss 0.0483530
# Validation loss decreased (0.066483 --> 0.048353).  Saving model ...
# Updating learning rate to 0.0006400000000000002
# 	iters: 100/115, epoch: 3 | loss: 0.0440189
# Epoch: 3 cost time: 1.9650118350982666
# Epoch: 3, Steps: 115 | Train Loss: 0.0444193 Test Loss 0.0414433
# Validation loss decreased (0.048353 --> 0.041443).  Saving model ...
# Updating learning rate to 0.0005120000000000001
# 	iters: 100/115, epoch: 4 | loss: 0.0391671
# Epoch: 4 cost time: 2.04565691947937
# Epoch: 4, Steps: 115 | Train Loss: 0.0398724 Test Loss 0.0386405
# Validation loss decreased (0.041443 --> 0.038641).  Saving model ...
# Updating learning rate to 0.0004096000000000001
# 	iters: 100/115, epoch: 5 | loss: 0.0385845
# Epoch: 5 cost time: 2.213698148727417
# Epoch: 5, Steps: 115 | Train Loss: 0.0379829 Test Loss 0.0374807
# Validation loss decreased (0.038641 --> 0.037481).  Saving model ...
# Updating learning rate to 0.0003276800000000001
# 	iters: 100/115, epoch: 6 | loss: 0.0373488
# Epoch: 6 cost time: 2.184798240661621
# Epoch: 6, Steps: 115 | Train Loss: 0.0371893 Test Loss 0.0369837
# Validation loss decreased (0.037481 --> 0.036984).  Saving model ...
# Updating learning rate to 0.0002621440000000001
# 	iters: 100/115, epoch: 7 | loss: 0.0364433
# Epoch: 7 cost time: 2.341503620147705
# Epoch: 7, Steps: 115 | Train Loss: 0.0368224 Test Loss 0.0367496
# Validation loss decreased (0.036984 --> 0.036750).  Saving model ...
# Updating learning rate to 0.0002097152000000001
# 	iters: 100/115, epoch: 8 | loss: 0.0367518
# Epoch: 8 cost time: 2.6201579570770264
# Epoch: 8, Steps: 115 | Train Loss: 0.0366241 Test Loss 0.0366256
# Validation loss decreased (0.036750 --> 0.036626).  Saving model ...
# Updating learning rate to 0.0001677721600000001
# 	iters: 100/115, epoch: 9 | loss: 0.0365537
# Epoch: 9 cost time: 2.3136584758758545
# Epoch: 9, Steps: 115 | Train Loss: 0.0365631 Test Loss 0.0365662
# Validation loss decreased (0.036626 --> 0.036566).  Saving model ...
# Updating learning rate to 0.00013421772800000008
# 	iters: 100/115, epoch: 10 | loss: 0.0365105
# Epoch: 10 cost time: 2.3100922107696533
# Epoch: 10, Steps: 115 | Train Loss: 0.0365127 Test Loss 0.0365277
# Validation loss decreased (0.036566 --> 0.036528).  Saving model ...
#
#
# Train shape: (36800, 1, 1) (36800, 1, 1)
# Train mse:0.04500696435570717,Train mae:0.16772739589214325
# Train rmse:0.21214844286441803,Train mape:477.3181457519531
#
#
# >>>>>>>testing : test_IndRNN_Custom_ftS_sl5_ll1_pl1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 3684
# loading model
# test shape: (3680, 1, 1) (3680, 1, 1)
# Test mse:0.03652770817279816,Test mae:0.16136448085308075
# Test rmse:0.19112223386764526,Test mape:634.2855834960938

# %%
model, setting = go_model(args)
# Out:
# Args in experiment:
# {'is_training': 1, 'model_id': 'test', 'model': 'IndRNN', 'plot_flag': 1, 'test_dir': 'custom/', 'verbose': 1, 'data': 'Custom', 'root_path': 'custom/dataset/', 'data_path': 'data.csv', 'target': 'Close', 'scale': True, 'freq': 'b', 'checkpoints': 'custom/checkpoints/', 'checkpoint_flag': 1, 'n_closest': None, 'all_stations': 0, 'data_step': 1, 'min_num_nodes': 2, 'features': 'MS', 'seq_len': 5, 'label_len': 1, 'pred_len': 1, 'enc_in': 6, 'dec_in': 6, 'c_out': 1, 'd_model': 512, 'n_heads': 8, 'e_layers': 2, 'd_layers': 2, 'gnn_layers': 2, 'd_ff': 2048, 'moving_avg': 25, 'factor': 3, 'distil': True, 'dropout': 0.05, 'embed': 'timeF', 'activation': 'gelu', 'output_attention': False, 'win_len': 6, 'res_len': None, 'qk_ker': 4, 'v_conv': 0, 'sparse_flag': 1, 'top_keys': 0, 'kernel_size': 3, 'train_strat_lstm': 'recursive', 'norm_out': 1, 'num_decomp': 4, 'mlp_out': 0, 'num_workers': 1, 'itr': 1, 'train_epochs': 10, 'batch_size': 32, 'patience': 5, 'learning_rate': 0.001, 'lr_decay_rate': 0.8, 'des': 'test', 'loss': 'mse', 'lradj': 'type1', 'use_gpu': False, 'gpu': 0, 'use_multi_gpu': False, 'devices': '0,1,2,3', 'criteria': 'default', 'kind_of_optim': 'default', 'kind_of_scaler': 'MinMax'}
# Use CPU
# >>>>>>>start training : test_IndRNN_Custom_ftMS_sl5_ll1_pl1_0>>>>>>>>>>>>>>>>>>>>>>>>>>
# train 3684
# test 3684
# Could not load best model
# Updating learning rate to 0.001
# 	iters: 100/115, epoch: 1 | loss: 0.0902099
# Epoch: 1 cost time: 1.7842960357666016
# Epoch: 1, Steps: 115 | Train Loss: 0.0876542 Test Loss 0.0665461
# Validation loss decreased (inf --> 0.066546).  Saving model ...
# Updating learning rate to 0.0008
# 	iters: 100/115, epoch: 2 | loss: 0.0561231
# Epoch: 2 cost time: 1.7151117324829102
# Epoch: 2, Steps: 115 | Train Loss: 0.0564333 Test Loss 0.0484061
# Validation loss decreased (0.066546 --> 0.048406).  Saving model ...
# Updating learning rate to 0.0006400000000000002
# 	iters: 100/115, epoch: 3 | loss: 0.0441944
# Epoch: 3 cost time: 1.927647352218628
# Epoch: 3, Steps: 115 | Train Loss: 0.0443771 Test Loss 0.0414175
# Validation loss decreased (0.048406 --> 0.041418).  Saving model ...
# Updating learning rate to 0.0005120000000000001
# 	iters: 100/115, epoch: 4 | loss: 0.0401140
# Epoch: 4 cost time: 1.9604759216308594
# Epoch: 4, Steps: 115 | Train Loss: 0.0397718 Test Loss 0.0385888
# Validation loss decreased (0.041418 --> 0.038589).  Saving model ...
# Updating learning rate to 0.0004096000000000001
# 	iters: 100/115, epoch: 5 | loss: 0.0373863
# Epoch: 5 cost time: 2.01404070854187
# Epoch: 5, Steps: 115 | Train Loss: 0.0379512 Test Loss 0.0374864
# Validation loss decreased (0.038589 --> 0.037486).  Saving model ...
# Updating learning rate to 0.0003276800000000001
# 	iters: 100/115, epoch: 6 | loss: 0.0375263
# Epoch: 6 cost time: 2.2856359481811523
# Epoch: 6, Steps: 115 | Train Loss: 0.0371571 Test Loss 0.0369744
# Validation loss decreased (0.037486 --> 0.036974).  Saving model ...
# Updating learning rate to 0.0002621440000000001
# 	iters: 100/115, epoch: 7 | loss: 0.0366988
# Epoch: 7 cost time: 2.2285618782043457
# Epoch: 7, Steps: 115 | Train Loss: 0.0368203 Test Loss 0.0367511
# Validation loss decreased (0.036974 --> 0.036751).  Saving model ...
# Updating learning rate to 0.0002097152000000001
# 	iters: 100/115, epoch: 8 | loss: 0.0362368
# Epoch: 8 cost time: 2.46012282371521
# Epoch: 8, Steps: 115 | Train Loss: 0.0366172 Test Loss 0.0366266
# Validation loss decreased (0.036751 --> 0.036627).  Saving model ...
# Updating learning rate to 0.0001677721600000001
# 	iters: 100/115, epoch: 9 | loss: 0.0358597
# Epoch: 9 cost time: 2.335300922393799
# Epoch: 9, Steps: 115 | Train Loss: 0.0365723 Test Loss 0.0365606
# Validation loss decreased (0.036627 --> 0.036561).  Saving model ...
# Updating learning rate to 0.00013421772800000008
# 	iters: 100/115, epoch: 10 | loss: 0.0363957
# Epoch: 10 cost time: 2.306692361831665
# Epoch: 10, Steps: 115 | Train Loss: 0.0365295 Test Loss 0.0365255
# Validation loss decreased (0.036561 --> 0.036526).  Saving model ...
#
#
# Train shape: (36800, 1, 1) (36800, 1, 1)
# Train mse:0.044988397508859634,Train mae:0.16767843067646027
# Train rmse:0.2121046781539917,Train mape:483.0462951660156
#
#
# >>>>>>>testing : test_IndRNN_Custom_ftMS_sl5_ll1_pl1_0<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<<
# test 3684
# loading model
# test shape: (3680, 1, 1) (3680, 1, 1)
# Test mse:0.036525506526231766,Test mae:0.1613779217004776
# Test rmse:0.19111646711826324,Test mape:634.6195678710938
